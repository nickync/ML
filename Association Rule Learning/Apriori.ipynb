# %% [markdown]
# <a href="https://colab.research.google.com/github/nickync/Machine-Learning/blob/main/Association%20Rule%20Learning/Apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # import dataset

# %%
dataset = pd.read_csv('marketbasket.csv')

# %% [markdown]
# # preprocess dataset

# %%
dataset = dataset.astype('str')

for i in range(0, 1361):
    for j in range(0, 255):
        if dataset.values[i,j] == '0':
            dataset.values[i,j] = 'nan'
        elif dataset.values[i,j] != 0:
            dataset.values[i,j] = dataset.columns[j]
display(dataset)
# Out:
#        Hair Conditioner  Lemons  ...   White Wine  Columbian Coffee
# 0                   nan     nan  ...          nan               nan
# 1                   nan     nan  ...          nan               nan
# 2                   nan     nan  ...          nan               nan
# 3                   nan     nan  ...          nan               nan
# 4                   nan     nan  ...          nan               nan
# ...                 ...     ...  ...          ...               ...
# 1356                nan     nan  ...   White Wine               nan
# 1357                nan     nan  ...          nan               nan
# 1358                nan     nan  ...          nan               nan
# 1359   Hair Conditioner     nan  ...          nan               nan
# 1360                nan     nan  ...          nan               nan
#
# [1361 rows x 255 columns]

# %% [markdown]
# # prepare training dataset

# %%
transactions = []
for i in range (0, 1361):
    transactions.append([dataset.values[i,j] for j in range (0, 255)])

# %% [markdown]
# # train the apriori model

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.03, min_confidence = 0.4, min_lift = 5, min_length = 2, max_length = 2 )

# %% [markdown]
# # show results

# %%
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({' Orange Juice', ' 2pct. Milk'}), support=0.03232916972814107, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Orange Juice'}), items_add=frozenset({' 2pct. Milk'}), confidence=0.5714285714285714, lift=5.219558964525407)]),
#  RelationRecord(items=frozenset({' Oranges', ' 2pct. Milk'}), support=0.03159441587068332, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Oranges'}), items_add=frozenset({' 2pct. Milk'}), confidence=0.5657894736842105, lift=5.168050158954434)]),
#  RelationRecord(items=frozenset({' Wheat Bread', ' 2pct. Milk'}), support=0.0426157237325496, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Wheat Bread'}), items_add=frozenset({' 2pct. Milk'}), confidence=0.5523809523809524, lift=5.045573665707894)]),
#  RelationRecord(items=frozenset({' Hamburger Buns', ' 98pct. Fat Free Hamburger'}), support=0.048493754592211606, ordered_statistics=[OrderedStatistic(items_base=frozenset({' 98pct. Fat Free Hamburger'}), items_add=frozenset({' Hamburger Buns'}), confidence=0.5196850393700787, lift=7.291663284357496), OrderedStatistic(items_base=frozenset({' Hamburger Buns'}), items_add=frozenset({' 98pct. Fat Free Hamburger'}), confidence=0.6804123711340206, lift=7.291663284357497)]),
#  RelationRecord(items=frozenset({' Toothpaste', ' Bologna'}), support=0.030124908155767818, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bologna'}), items_add=frozenset({' Toothpaste'}), confidence=0.4659090909090909, lift=5.871317340067339)]),
#  RelationRecord(items=frozenset({' Canned Tuna', ' White Bread'}), support=0.03306392358559882, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Canned Tuna'}), items_add=frozenset({' White Bread'}), confidence=0.6081081081081081, lift=5.108858858858858)]),
#  RelationRecord(items=frozenset({' Onions', ' Cola'}), support=0.03159441587068332, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cola'}), items_add=frozenset({' Onions'}), confidence=0.40566037735849053, lift=5.065172234723905)]),
#  RelationRecord(items=frozenset({' Cola', ' Toilet Paper'}), support=0.030124908155767818, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Toilet Paper'}), items_add=frozenset({' Cola'}), confidence=0.40594059405940597, lift=5.212124042592939)]),
#  RelationRecord(items=frozenset({' Toothpaste', ' Cola'}), support=0.034533431300514325, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cola'}), items_add=frozenset({' Toothpaste'}), confidence=0.44339622641509435, lift=5.58761355695318), OrderedStatistic(items_base=frozenset({' Toothpaste'}), items_add=frozenset({' Cola'}), confidence=0.4351851851851851, lift=5.587613556953179)]),
#  RelationRecord(items=frozenset({' Wheat Bread', ' Cola'}), support=0.03232916972814107, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cola'}), items_add=frozenset({' Wheat Bread'}), confidence=0.41509433962264153, lift=5.38041329739443), OrderedStatistic(items_base=frozenset({' Wheat Bread'}), items_add=frozenset({' Cola'}), confidence=0.41904761904761906, lift=5.38041329739443)]),
#  RelationRecord(items=frozenset({' Onions', ' Domestic Beer'}), support=0.030124908155767818, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Domestic Beer'}), items_add=frozenset({' Onions'}), confidence=0.44565217391304346, lift=5.564519345831671)]),
#  RelationRecord(items=frozenset({' Pepperoni Pizza - Frozen', ' Domestic Beer'}), support=0.036737692872887584, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Domestic Beer'}), items_add=frozenset({' Pepperoni Pizza - Frozen'}), confidence=0.5434782608695652, lift=7.868871415356152), OrderedStatistic(items_base=frozenset({' Pepperoni Pizza - Frozen'}), items_add=frozenset({' Domestic Beer'}), confidence=0.5319148936170214, lift=7.868871415356153)]),
#  RelationRecord(items=frozenset({' Salsa Dip', ' Eggs'}), support=0.03085966201322557, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Salsa Dip'}), items_add=frozenset({' Eggs'}), confidence=0.6176470588235294, lift=5.033638605142656)]),
#  RelationRecord(items=frozenset({' Sugar Cookies', ' Eggs'}), support=0.036737692872887584, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Sugar Cookies'}), items_add=frozenset({' Eggs'}), confidence=0.6666666666666666, lift=5.433133732534929)]),
#  RelationRecord(items=frozenset({' Hot Dog Buns', ' Hot Dogs'}), support=0.04188096987509184, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Hot Dog Buns'}), items_add=frozenset({' Hot Dogs'}), confidence=0.7125, lift=7.696130952380953), OrderedStatistic(items_base=frozenset({' Hot Dogs'}), items_add=frozenset({' Hot Dog Buns'}), confidence=0.4523809523809524, lift=7.696130952380953)]),
#  RelationRecord(items=frozenset({' Hot Dog Buns', ' Sweet Relish'}), support=0.03600293901542983, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Hot Dog Buns'}), items_add=frozenset({' Sweet Relish'}), confidence=0.6124999999999999, lift=7.186314655172413), OrderedStatistic(items_base=frozenset({' Sweet Relish'}), items_add=frozenset({' Hot Dog Buns'}), confidence=0.42241379310344823, lift=7.1863146551724135)]),
#  RelationRecord(items=frozenset({' Hot Dogs', ' Sweet Relish'}), support=0.0470242468772961, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Hot Dogs'}), items_add=frozenset({' Sweet Relish'}), confidence=0.5079365079365079, lift=5.9594964422550625), OrderedStatistic(items_base=frozenset({' Sweet Relish'}), items_add=frozenset({' Hot Dogs'}), confidence=0.5517241379310344, lift=5.959496442255062)]),
#  RelationRecord(items=frozenset({' Onions', ' Toothpaste'}), support=0.03526818515797208, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Onions'}), items_add=frozenset({' Toothpaste'}), confidence=0.44036697247706424, lift=5.549439347604485), OrderedStatistic(items_base=frozenset({' Toothpaste'}), items_add=frozenset({' Onions'}), confidence=0.4444444444444444, lift=5.549439347604485)]),
#  RelationRecord(items=frozenset({' Onions', ' Wheat Bread'}), support=0.034533431300514325, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Onions'}), items_add=frozenset({' Wheat Bread'}), confidence=0.4311926605504587, lift=5.589078200087374), OrderedStatistic(items_base=frozenset({' Wheat Bread'}), items_add=frozenset({' Onions'}), confidence=0.4476190476190476, lift=5.589078200087374)]),
#  RelationRecord(items=frozenset({' Popcorn Salt', ' Potato Chips'}), support=0.03232916972814107, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Popcorn Salt'}), items_add=frozenset({' Potato Chips'}), confidence=0.5057471264367815, lift=5.1753521735372905)]),
#  RelationRecord(items=frozenset({' Potato Chips', ' Tomatoes'}), support=0.03232916972814107, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Tomatoes'}), items_add=frozenset({' Potato Chips'}), confidence=0.48888888888888893, lift=5.002840434419382)]),
#  RelationRecord(items=frozenset({' Sugar Cookies', ' White Bread'}), support=0.03526818515797208, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Sugar Cookies'}), items_add=frozenset({' White Bread'}), confidence=0.64, lift=5.37679012345679)]),
#  RelationRecord(items=frozenset({' Tomatoes', ' Sweet Relish'}), support=0.030124908155767818, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Tomatoes'}), items_add=frozenset({' Sweet Relish'}), confidence=0.4555555555555556, lift=5.34492337164751)]),
#  RelationRecord(items=frozenset({' Toothpaste', ' Sweet Relish'}), support=0.03747244673034533, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Sweet Relish'}), items_add=frozenset({' Toothpaste'}), confidence=0.43965517241379304, lift=5.540469348659003), OrderedStatistic(items_base=frozenset({' Toothpaste'}), items_add=frozenset({' Sweet Relish'}), confidence=0.47222222222222215, lift=5.540469348659003)]),
#  RelationRecord(items=frozenset({' Toothpaste', ' Tomatoes'}), support=0.03085966201322557, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Tomatoes'}), items_add=frozenset({' Toothpaste'}), confidence=0.46666666666666673, lift=5.880864197530864)]),
#  RelationRecord(items=frozenset({' White Bread', ' Tomatoes'}), support=0.04041146216017634, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Tomatoes'}), items_add=frozenset({' White Bread'}), confidence=0.6111111111111112, lift=5.134087791495199)]),
#  RelationRecord(items=frozenset({' Wheat Bread', ' Toothpaste'}), support=0.034533431300514325, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Toothpaste'}), items_add=frozenset({' Wheat Bread'}), confidence=0.4351851851851851, lift=5.640828924162257), OrderedStatistic(items_base=frozenset({' Wheat Bread'}), items_add=frozenset({' Toothpaste'}), confidence=0.4476190476190476, lift=5.640828924162257)]),
#  RelationRecord(items=frozenset({' Toothpaste', ' White Bread'}), support=0.04775900073475386, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Toothpaste'}), items_add=frozenset({' White Bread'}), confidence=0.6018518518518519, lift=5.056298582533151), OrderedStatistic(items_base=frozenset({' White Bread'}), items_add=frozenset({' Toothpaste'}), confidence=0.4012345679012346, lift=5.056298582533151)])]

# %% [markdown]
# # show results in dataframe

# %%
def inspect(results):
    lhs = [tuple(result[2][0][0])[0] for result in results]
    rhs = [tuple(result[2][0][1])[0] for result in results]
    supports = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidences', 'lifts'])

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'lifts')
# Out:
#                 Left Hand Side  ...     lifts
# 11               Domestic Beer  ...  7.868871
# 14                Hot Dog Buns  ...  7.696131
# 3    98pct. Fat Free Hamburger  ...  7.291663
# 15                Hot Dog Buns  ...  7.186315
# 16                    Hot Dogs  ...  5.959496
# 24                    Tomatoes  ...  5.880864
# 4                      Bologna  ...  5.871317
# 26                  Toothpaste  ...  5.640829
# 18                      Onions  ...  5.589078
# 8                         Cola  ...  5.587614
#
# [10 rows x 5 columns]
